# %% [markdown]
# # Integration example using SSSOM mappings of country classification

# %%
import pandas as pd
import os
from IPython.display import clear_output
import requests
import json
from fuzzywuzzy import fuzz
from datetime import datetime

# %% [markdown]
# ## Load original SDG dataset

# %% [markdown]
# ### 1.a Data

# %%
data_sdg = pd.read_csv('../datasets/observations_SI_POV_EMP1.csv', dtype=str).fillna('')
data_sdg.head(3)
# Out:
#    SERIES_CODE                                 SERIES_DESCRIPTION  \
# 0  SI_POV_EMP1  Employed population below international povert...
# 1  SI_POV_EMP1  Employed population below international povert...
# 2  SI_POV_EMP1  Employed population below international povert...
#
#              VARIABLE_CODE                               VARIABLE_DESCRIPTION  \
# 0  SI_POV_EMP1@AGE--Y15T24  Employed population below international povert...
# 1  SI_POV_EMP1@AGE--Y15T24  Employed population below international povert...
# 2  SI_POV_EMP1@AGE--Y15T24  Employed population below international povert...
#
#   VARIABLE_ACTIVE_DIMS GEOGRAPHY_CODE GEOGRAPHY_NAME GEOGRAPHY_TYPE  \
# 0              ['AGE']              1          World         Region
# 1              ['AGE']              1          World         Region
# 2              ['AGE']              1          World         Region
#
#   GEO_AREA_CODE GEO_AREA_NAME  ... UNIT_MULT BASE_PERIOD NATURE  \
# 0             1         World  ...                            N
# 1             1         World  ...                            N
# 2             1         World  ...                            N
#
#                                        SOURCE GEO_INFO_URL FOOT_NOTE  \
# 0  Source = ILO modelled estimates, Nov. 2022
# 1  Source = ILO modelled estimates, Nov. 2022
# 2  Source = ILO modelled estimates, Nov. 2022
#
#   REPORTING_TYPE OBS_STATUS RELEASE_STATUS  RELEASE_NAME
# 0              G          E      Published  2023.Q2.G.01
# 1              G          E      Published  2023.Q2.G.01
# 2              G          E      Published  2023.Q2.G.01
#
# [3 rows x 34 columns]

# %% [markdown]
# ### 2a. Schema

# %%
schema_sdg = list(data_sdg)
schema_sdg = [{'ConceptID': x, 'ConceptName': x.replace("_", " ").title()} for x in schema_sdg]
for x in schema_sdg:
    if x['ConceptID'] in ['SERIES_CODE', 'GEOGRAPHY_CODE',
                          'FREQ', 'AGE', 'SEX', 
                         ]:
        x['Coded'] = True
        x['Role'] = 'Dimension'
    elif x['ConceptID'] in ['VARIABLE_CODE', 'GEO_AREA_CODE', 'CITIES', 'SAMPLING_STATIONS', 'IS_LATEST_PERIOD', 
                           'VALUE_TYPE', 'UNIT_MEASURE', 'UNIT_MULT', 'NATURE', 'REPORTING_TYPE', 'OBS_STATUS']:
        
        x['Coded'] = True
        x['Role'] = 'Attribute'
    elif x['ConceptID'] == 'TIME_PERIOD':
        x['Coded'] = False
        x['Role'] = 'TimeDimension'
    elif x['ConceptID'] == 'OBS_VALUE':
        x['Coded'] = False
        x['Role'] = 'Measurement'
    else:
        x['Coded'] = False
        x['Role'] = 'Attribute'

    x['ConceptID'] = 'sdg:' + x['ConceptID']
        
    
schema_sdg= pd.DataFrame(schema_sdg)
schema_sdg
# Out:
#                    ConceptID           ConceptName  Coded           Role
# 0            sdg:SERIES_CODE           Series Code   True      Dimension
# 1     sdg:SERIES_DESCRIPTION    Series Description  False      Attribute
# 2          sdg:VARIABLE_CODE         Variable Code   True      Attribute
# 3   sdg:VARIABLE_DESCRIPTION  Variable Description  False      Attribute
# 4   sdg:VARIABLE_ACTIVE_DIMS  Variable Active Dims  False      Attribute
# 5         sdg:GEOGRAPHY_CODE        Geography Code   True      Dimension
# 6         sdg:GEOGRAPHY_NAME        Geography Name  False      Attribute
# 7         sdg:GEOGRAPHY_TYPE        Geography Type  False      Attribute
# 8          sdg:GEO_AREA_CODE         Geo Area Code   True      Attribute
# 9          sdg:GEO_AREA_NAME         Geo Area Name  False      Attribute
# 10                sdg:CITIES                Cities   True      Attribute
# 11     sdg:SAMPLING_STATIONS     Sampling Stations   True      Attribute
# 12      sdg:IS_LATEST_PERIOD      Is Latest Period   True      Attribute
# 13           sdg:TIME_PERIOD           Time Period  False  TimeDimension
# 14           sdg:TIME_DETAIL           Time Detail  False      Attribute
# 15         sdg:TIME_COVERAGE         Time Coverage  False      Attribute
# 16                  sdg:FREQ                  Freq   True      Dimension
# 17                   sdg:AGE                   Age   True      Dimension
# 18                   sdg:SEX                   Sex   True      Dimension
# 19             sdg:OBS_VALUE             Obs Value  False    Measurement
# 20            sdg:VALUE_TYPE            Value Type   True      Attribute
# 21           sdg:UPPER_BOUND           Upper Bound  False      Attribute
# 22           sdg:LOWER_BOUND           Lower Bound  False      Attribute
# 23          sdg:UNIT_MEASURE          Unit Measure   True      Attribute
# 24             sdg:UNIT_MULT             Unit Mult   True      Attribute
# 25           sdg:BASE_PERIOD           Base Period  False      Attribute
# 26                sdg:NATURE                Nature   True      Attribute
# 27                sdg:SOURCE                Source  False      Attribute
# 28          sdg:GEO_INFO_URL          Geo Info Url  False      Attribute
# 29             sdg:FOOT_NOTE             Foot Note  False      Attribute
# 30        sdg:REPORTING_TYPE        Reporting Type   True      Attribute
# 31            sdg:OBS_STATUS            Obs Status   True      Attribute
# 32        sdg:RELEASE_STATUS        Release Status  False      Attribute
# 33          sdg:RELEASE_NAME          Release Name  False      Attribute

# %% [markdown]
# ### 3a. Convert code values to IRIs in data table

# %%
for x in list(data_sdg):
    data_sdg.rename(columns={x: f'sdg:{x}'}, inplace=True)

for index, row in schema_sdg.iterrows():
    if row['Coded']:
        data_sdg[row["ConceptID"]] = data_sdg[row["ConceptID"]].apply(
            lambda x: f"{row['ConceptID']}/{x}" if x != '' else ''
        )
data_sdg.head(3)
# Out:
#                sdg:SERIES_CODE  \
# 0  sdg:SERIES_CODE/SI_POV_EMP1
# 1  sdg:SERIES_CODE/SI_POV_EMP1
# 2  sdg:SERIES_CODE/SI_POV_EMP1
#
#                               sdg:SERIES_DESCRIPTION  \
# 0  Employed population below international povert...
# 1  Employed population below international povert...
# 2  Employed population below international povert...
#
#                            sdg:VARIABLE_CODE  \
# 0  sdg:VARIABLE_CODE/SI_POV_EMP1@AGE--Y15T24
# 1  sdg:VARIABLE_CODE/SI_POV_EMP1@AGE--Y15T24
# 2  sdg:VARIABLE_CODE/SI_POV_EMP1@AGE--Y15T24
#
#                             sdg:VARIABLE_DESCRIPTION sdg:VARIABLE_ACTIVE_DIMS  \
# 0  Employed population below international povert...                  ['AGE']
# 1  Employed population below international povert...                  ['AGE']
# 2  Employed population below international povert...                  ['AGE']
#
#      sdg:GEOGRAPHY_CODE sdg:GEOGRAPHY_NAME sdg:GEOGRAPHY_TYPE  \
# 0  sdg:GEOGRAPHY_CODE/1              World             Region
# 1  sdg:GEOGRAPHY_CODE/1              World             Region
# 2  sdg:GEOGRAPHY_CODE/1              World             Region
#
#      sdg:GEO_AREA_CODE sdg:GEO_AREA_NAME  ... sdg:UNIT_MULT sdg:BASE_PERIOD  \
# 0  sdg:GEO_AREA_CODE/1             World  ...
# 1  sdg:GEO_AREA_CODE/1             World  ...
# 2  sdg:GEO_AREA_CODE/1             World  ...
#
#      sdg:NATURE                                  sdg:SOURCE sdg:GEO_INFO_URL  \
# 0  sdg:NATURE/N  Source = ILO modelled estimates, Nov. 2022
# 1  sdg:NATURE/N  Source = ILO modelled estimates, Nov. 2022
# 2  sdg:NATURE/N  Source = ILO modelled estimates, Nov. 2022
#
#   sdg:FOOT_NOTE    sdg:REPORTING_TYPE    sdg:OBS_STATUS sdg:RELEASE_STATUS  \
# 0                sdg:REPORTING_TYPE/G  sdg:OBS_STATUS/E          Published
# 1                sdg:REPORTING_TYPE/G  sdg:OBS_STATUS/E          Published
# 2                sdg:REPORTING_TYPE/G  sdg:OBS_STATUS/E          Published
#
#   sdg:RELEASE_NAME
# 0     2023.Q2.G.01
# 1     2023.Q2.G.01
# 2     2023.Q2.G.01
#
# [3 rows x 34 columns]

# %% [markdown]
# ### 4a. Geography code list

# %%
cl_geo_sdg = data_sdg[['sdg:GEOGRAPHY_CODE', 'sdg:GEOGRAPHY_NAME']].drop_duplicates().reset_index(drop=True)
cl_geo_sdg.rename(columns={
                            'sdg:GEOGRAPHY_CODE': 'CodeID',
                            'sdg:GEOGRAPHY_NAME': 'CodeDescription'
                        }, inplace=True)
cl_geo_sdg
# Out:
#                      CodeID                     CodeDescription
# 0      sdg:GEOGRAPHY_CODE/1                               World
# 1      sdg:GEOGRAPHY_CODE/2                              Africa
# 2      sdg:GEOGRAPHY_CODE/5                       South America
# 3      sdg:GEOGRAPHY_CODE/8                             Albania
# 4      sdg:GEOGRAPHY_CODE/9                             Oceania
# ..                      ...                                 ...
# 155  sdg:GEOGRAPHY_CODE/858                             Uruguay
# 156  sdg:GEOGRAPHY_CODE/860                          Uzbekistan
# 157  sdg:GEOGRAPHY_CODE/862  Venezuela (Bolivarian Republic of)
# 158  sdg:GEOGRAPHY_CODE/887                               Yemen
# 159  sdg:GEOGRAPHY_CODE/894                              Zambia
#
# [160 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 1b. Data table

# %%
data_ilo = pd.read_csv('../datasets/ILO Labour income distribution.csv', dtype=str).fillna('')
data_ilo.head(3)
# Out:
#                       DATAFLOW REF_AREA FREQ      MEASURE            QTL  \
# 0  ILO:DF_LAP_2LID_QTL_RT(1.0)      AFG    A  LAP_2LID_RT  QTL_DECILE_01
# 1  ILO:DF_LAP_2LID_QTL_RT(1.0)      AFG    A  LAP_2LID_RT  QTL_DECILE_02
# 2  ILO:DF_LAP_2LID_QTL_RT(1.0)      AFG    A  LAP_2LID_RT  QTL_DECILE_03
#
#   TIME_PERIOD OBS_VALUE OBS_STATUS UNIT_MEASURE_TYPE UNIT_MEASURE UNIT_MULT  \
# 0        2013      0.44          M                RT           PT         0
# 1        2013      1.01          M                RT           PT         0
# 2        2013       1.7          M                RT           PT         0
#
#                      SOURCE NOTE_SOURCE NOTE_INDICATOR NOTE_CLASSIF DECIMALS  \
# 0  ILO - Modelled Estimates                                                1
# 1  ILO - Modelled Estimates                                                1
# 2  ILO - Modelled Estimates                                                1
#
#   UPPER_BOUND LOWER_BOUND
# 0
# 1
# 2

# %%
list(data_ilo)
# Out:
# ['DATAFLOW',
#  'REF_AREA',
#  'FREQ',
#  'MEASURE',
#  'QTL',
#  'TIME_PERIOD',
#  'OBS_VALUE',
#  'OBS_STATUS',
#  'UNIT_MEASURE_TYPE',
#  'UNIT_MEASURE',
#  'UNIT_MULT',
#  'SOURCE',
#  'NOTE_SOURCE',
#  'NOTE_INDICATOR',
#  'NOTE_CLASSIF',
#  'DECIMALS',
#  'UPPER_BOUND',
#  'LOWER_BOUND']

# %% [markdown]
# ### 2b. Schema

# %%
schema_ilo = list(data_ilo)
schema_ilo = [{'ConceptID': x, 'ConceptName': x.replace("_", " ").title()} for x in schema_ilo]

for x in schema_ilo:
    if x['ConceptID'] in ['REF_AREA', 'FREQ', 'MEASURE', 'QTL'] :
        x['Coded'] = True
        x['Role'] = 'Dimension'
    elif x['ConceptID'] in ['UNIT_MEASURE_TYPE', 'UNIT_MEASURE', 'UNIT_MULT','OBS_STATUS']:
        x['Coded'] = True
        x['Role'] = 'Attribute'
    elif x['ConceptID'] == 'TIME_PERIOD':
        x['Coded'] = False
        x['Role'] = 'TimeDimension'
    elif x['ConceptID'] == 'OBS_VALUE':
        x['Coded'] = False
        x['Role'] = 'Measurement'
    else:
        x['Coded'] = False
        x['Role'] = 'Attribute'

    x['ConceptID'] = 'ilo:' + x['ConceptID']
        
    
schema_ilo= pd.DataFrame(schema_ilo)
schema_ilo
# Out:
#                 ConceptID        ConceptName  Coded           Role
# 0            ilo:DATAFLOW           Dataflow  False      Attribute
# 1            ilo:REF_AREA           Ref Area   True      Dimension
# 2                ilo:FREQ               Freq   True      Dimension
# 3             ilo:MEASURE            Measure   True      Dimension
# 4                 ilo:QTL                Qtl   True      Dimension
# 5         ilo:TIME_PERIOD        Time Period  False  TimeDimension
# 6           ilo:OBS_VALUE          Obs Value  False    Measurement
# 7          ilo:OBS_STATUS         Obs Status   True      Attribute
# 8   ilo:UNIT_MEASURE_TYPE  Unit Measure Type   True      Attribute
# 9        ilo:UNIT_MEASURE       Unit Measure   True      Attribute
# 10          ilo:UNIT_MULT          Unit Mult   True      Attribute
# 11             ilo:SOURCE             Source  False      Attribute
# 12        ilo:NOTE_SOURCE        Note Source  False      Attribute
# 13     ilo:NOTE_INDICATOR     Note Indicator  False      Attribute
# 14       ilo:NOTE_CLASSIF       Note Classif  False      Attribute
# 15           ilo:DECIMALS           Decimals  False      Attribute
# 16        ilo:UPPER_BOUND        Upper Bound  False      Attribute
# 17        ilo:LOWER_BOUND        Lower Bound  False      Attribute

# %% [markdown]
# ### 3b. Convert code values to IRIs in data table

# %%
for x in list(data_ilo):
    data_ilo.rename(columns={x: f'ilo:{x}'}, inplace=True)

for index, row in schema_ilo.iterrows():
    if row['Coded']:
        data_ilo[row["ConceptID"]] = data_ilo[row["ConceptID"]].apply(
            lambda x: f"{row['ConceptID']}/{x}" if x != '' else ''
        )

data_ilo.head(3)
# Out:
#                   ilo:DATAFLOW      ilo:REF_AREA    ilo:FREQ  \
# 0  ILO:DF_LAP_2LID_QTL_RT(1.0)  ilo:REF_AREA/AFG  ilo:FREQ/A
# 1  ILO:DF_LAP_2LID_QTL_RT(1.0)  ilo:REF_AREA/AFG  ilo:FREQ/A
# 2  ILO:DF_LAP_2LID_QTL_RT(1.0)  ilo:REF_AREA/AFG  ilo:FREQ/A
#
#                ilo:MEASURE                ilo:QTL ilo:TIME_PERIOD  \
# 0  ilo:MEASURE/LAP_2LID_RT  ilo:QTL/QTL_DECILE_01            2013
# 1  ilo:MEASURE/LAP_2LID_RT  ilo:QTL/QTL_DECILE_02            2013
# 2  ilo:MEASURE/LAP_2LID_RT  ilo:QTL/QTL_DECILE_03            2013
#
#   ilo:OBS_VALUE    ilo:OBS_STATUS     ilo:UNIT_MEASURE_TYPE  \
# 0          0.44  ilo:OBS_STATUS/M  ilo:UNIT_MEASURE_TYPE/RT
# 1          1.01  ilo:OBS_STATUS/M  ilo:UNIT_MEASURE_TYPE/RT
# 2           1.7  ilo:OBS_STATUS/M  ilo:UNIT_MEASURE_TYPE/RT
#
#       ilo:UNIT_MEASURE    ilo:UNIT_MULT                ilo:SOURCE  \
# 0  ilo:UNIT_MEASURE/PT  ilo:UNIT_MULT/0  ILO - Modelled Estimates
# 1  ilo:UNIT_MEASURE/PT  ilo:UNIT_MULT/0  ILO - Modelled Estimates
# 2  ilo:UNIT_MEASURE/PT  ilo:UNIT_MULT/0  ILO - Modelled Estimates
#
#   ilo:NOTE_SOURCE ilo:NOTE_INDICATOR ilo:NOTE_CLASSIF ilo:DECIMALS  \
# 0                                                                1
# 1                                                                1
# 2                                                                1
#
#   ilo:UPPER_BOUND ilo:LOWER_BOUND
# 0
# 1
# 2

# %% [markdown]
# ### 4b. Geography code list

# %%
cl_geo_ilo = pd.read_csv('../enumerations/ILO__CL_AREA(1.0).csv', dtype=str).fillna('')
cl_geo_ilo.head(3)

cl_geo_ilo = cl_geo_ilo[['code_id', 'code_name']].drop_duplicates().reset_index(drop=True)
cl_geo_ilo.rename(columns={
                            'code_id': 'CodeID',
                            'code_name': 'CodeDescription'
                        }, inplace=True)

cl_geo_ilo['CodeID'] = 'ilo:REF_AREA/' + cl_geo_ilo['CodeID']
cl_geo_ilo
# Out:
#                CodeID                                    CodeDescription
# 0    ilo:REF_AREA/AGO                                             Angola
# 1    ilo:REF_AREA/BDI                                            Burundi
# 2    ilo:REF_AREA/BEN                                              Benin
# 3    ilo:REF_AREA/BFA                                       Burkina Faso
# 4    ilo:REF_AREA/BWA                                           Botswana
# ..                ...                                                ...
# 326  ilo:REF_AREA/X25                              Americas: High income
# 327  ilo:REF_AREA/X01                                              World
# 328  ilo:REF_AREA/X59                 Southern Asia: Upper-middle income
# 329  ilo:REF_AREA/X65  Northern, Southern and Western Europe: Upper-m...
# 330   ilo:REF_AREA/_Z                                     Not Applicable
#
# [331 rows x 2 columns]

# %% [markdown]
# ---

# %%
with pd.ExcelWriter('../inputs/sdg_dataset.xlsx', engine='xlsxwriter') as writer:
    # Write each DataFrame to a specific sheet
    data_sdg.to_excel(writer, sheet_name='data', index=False)
    schema_sdg.to_excel(writer, sheet_name='schema', index=False)
    cl_geo_sdg.to_excel(writer, sheet_name='cl_geo', index=False)

# %%
with pd.ExcelWriter('../inputs/ilo_dataset.xlsx', engine='xlsxwriter') as writer:
    # Write each DataFrame to a specific sheet
    data_ilo.to_excel(writer, sheet_name='data', index=False)
    schema_ilo.to_excel(writer, sheet_name='schema', index=False)
    cl_geo_ilo.to_excel(writer, sheet_name='cl_geo', index=False)
